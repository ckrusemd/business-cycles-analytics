# %% [markdown]
# # (BYGV88) : Det samlede etageareal (korrigeret for forsinkelser) efter byggefase, anvendelse, bygherreforhold og sæsonkorrigering

# %%
from functions import *

# %% [markdown]
# ## Påbegyndt byggeri

# %%
df = get_dst_dataframe('BYGV88')
df = df[df['BYGFASE']=='Påbegyndt byggeri']
df = df[df['SÆSON']=='Sæsonkorrigeret']
df = df[df['BYGHERRE']=='I alt']
df = df[df['ANVENDELSE']=='Anvendelse i alt']

# %%
tune_and_predict( dates = df['TID'].values, values = df['INDHOLD'].values, n_ahead=2*365  )
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8df8ae7eb0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8df8d87bb0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8df8a67310>
# ...

# %% [markdown]
# ## Fuldført byggeri

# %%
df = get_dst_dataframe('BYGV88')
df = df[df['BYGFASE']=='Fuldført byggeri']
df = df[df['SÆSON']=='Sæsonkorrigeret']
df = df[df['BYGHERRE']=='I alt']
df = df[df['ANVENDELSE']=='Anvendelse i alt']

# %%
tune_and_predict( dates = df['TID'].values, values = df['INDHOLD'].values, n_ahead=2*365  )
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da5438eb0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da542d250>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da53d8940>
# ...

# %% [markdown]
# ## Byggeri under opførelse

# %%
df = get_dst_dataframe('BYGV88')
df = df[df['BYGFASE']=='Byggeri under opførelse']
df = df[df['SÆSON']=='Sæsonkorrigeret']
df = df[df['BYGHERRE']=='I alt']
df = df[df['ANVENDELSE']=='Anvendelse i alt']

# %%
tune_and_predict( dates = df['TID'].values, values = df['INDHOLD'].values, n_ahead=2*365  )
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da5595e50>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da51c1340>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da51c1280>
# ...

# %% [markdown]
# ## Tilladt byggeri

# %%
df = get_dst_dataframe('BYGV88')
df = df[df['BYGFASE']=='Tilladt byggeri']
df = df[df['SÆSON']=='Sæsonkorrigeret']
df = df[df['BYGHERRE']=='I alt']
df = df[df['ANVENDELSE']=='Anvendelse i alt']

# %%
tune_and_predict( dates = df['TID'].values, values = df['INDHOLD'].values, n_ahead=2 * 365  )
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da51486d0>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da53d1040>
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f8da507edc0>
# ...
